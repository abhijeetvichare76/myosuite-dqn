# %%
# import myosuite
# import gym
# import time
# env = gym.make("myoChallengeDieReorientP1-v0")
# env.reset()
# for _ in range(1000):
#     env.sim.render(mode='window')
#     env.step(env.action_space.sample()) # take a random action
#     time.sleep(0.1)
# env.reset()
# env.close()
# Out:
# RS:> Registering Myo Envs
# Creating window glfw

# %%
import myosuite
import gym
import time
env = gym.make("myoChallengeDieReorientP1-v0")
env.reset()
for _ in range(10):
    # env.sim.render(mode='window')
    print(env.action_space.sample())
    env.step(env.action_space.sample()) # take a random action
    time.sleep(0.1)
env.reset()
env.close()
# Out:
# RS:> Registering Myo Envs
# [ 8.5210e-01 -3.3945e-01  9.7220e-04  1.8839e-01 -3.4171e-02  8.0592e-01
#   4.2232e-04  4.7036e-01 -9.0812e-01 -9.1480e-01  8.0187e-02 -3.3426e-01
#  -8.1433e-01  4.6529e-01 -8.0604e-01  1.5906e-01  9.7771e-01  4.7233e-01
#   8.8144e-01  6.5257e-01  6.5410e-01  6.3289e-01  7.4644e-01 -8.0636e-01
#   9.8053e-02  2.7671e-01  3.2260e-01  9.9483e-01 -4.1461e-01  6.5783e-01
#  -9.9213e-01 -8.7527e-01 -6.7818e-01 -9.8776e-01  5.5860e-01 -9.2179e-02
#  -9.5118e-01 -7.1209e-01 -2.8664e-01]
# [-0.5105 -0.1271 -0.6936 -0.7198  0.5496 -0.9553  0.3432  0.6061 -0.7654
#   0.1482 -0.0546 -0.4553 -0.8545  0.9103 -0.5133  0.7103 -0.6632  0.3611
#  -0.289  -0.2456 -0.1379 -0.6778 -0.577   0.5981  0.8809 -0.6223 -0.575
#  -0.7599  0.5936  0.321  -0.5547 -0.4213 -0.5488  0.153  -0.009  -0.7905
#   0.2797  0.9765 -0.7464]
# [-0.4933 -0.2518  0.7294 -0.4055  0.2184 -0.898  -0.7658 -0.5156  0.0885
#   0.5459  0.698   0.5483 -0.1875 -0.3507 -0.6417  0.879   0.205  -0.2225
#   0.8394  0.5048 -0.8684 -0.3863  0.5814  0.5873  0.1615  0.5839  0.4252
#  -0.9739  0.1034 -0.3651  0.4671  0.6834  0.533   0.5184 -0.9115 -0.7955
#  -0.8733 -0.3598 -0.2606]
# [ 0.327   0.5394 -0.1043 -0.7321 -0.3865 -0.8378  0.3232 -0.2387 -0.9858
#  -0.8338 -0.7771 -0.609  -0.1043  0.3643 -0.6282 -0.7779 -0.4084  0.3828
#   0.2244 -0.8122  0.0445  0.9478  0.2783  0.632  -0.2971 -0.9997  0.2792
#   0.1555 -0.194   0.7391  0.7708 -0.9242  0.9301  0.6858 -0.8707 -0.2725
#   0.444   0.0634  0.5928]
# [ 0.0037 -0.3176 -0.7831 -0.8437  0.2457 -0.085   0.5233  0.1237  0.0838
#  -0.7822 -0.3472 -0.3451  0.0307  0.9295  0.1718  0.1273  0.8515 -0.8899
#  -0.8835  0.8121  0.0058 -0.4359  0.4987  0.8893  0.7573 -0.0952 -0.4888
#   0.7698  0.6188  0.1438 -0.4543  0.2976 -0.5223 -0.3237  0.7218 -0.863
#  -0.4765 -0.8732 -0.4507]
# [ 0.4158 -0.2635 -0.697  -0.6373  0.9559  0.7455 -0.1715  0.9796 -0.4313
#  -0.6066 -0.7346  0.642  -0.5886  0.3297 -0.5995  0.9674 -0.6537 -0.3036
#   0.4853 -0.3874  0.8196 -0.566  -0.1576  0.2672  0.2615  0.311   0.262
#  -0.3951  0.3235  0.9644  0.7739 -0.8556  0.1699  0.7121  0.5186  0.844
#   0.4769 -0.7863  0.1049]
# [-0.4962  0.4331 -0.0976 -0.4057  0.756  -0.3853  0.0728 -0.9984 -0.741
#   0.7634 -0.0365 -0.4061 -0.4443  0.617  -0.8942  0.3664 -0.9131 -0.3354
#  -0.3777 -0.8884  0.6081 -0.5225 -0.1164 -0.9014  0.272   0.3281  0.4729
#  -0.5733 -0.0384 -0.3712 -0.671  -0.9933 -0.4573 -0.562   0.9526  0.4212
#  -0.4205 -0.4932 -0.0906]
# [-0.7375 -0.3521  0.2494  0.7936  0.4504 -0.1945  0.2719 -0.7291 -0.2978
#  -0.0818 -0.4665 -0.1279 -0.8191  0.8771 -0.1844  0.3942  0.1101 -0.587
#  -0.9972  0.4841 -0.0112 -0.2995 -0.6417  0.9283 -0.8235  0.1414 -0.5705
#   0.9751 -0.3722  0.2609 -0.6674  0.4326 -0.4866  0.2012  0.0172  0.917
#   0.7008  0.5228  0.2063]
# [-0.1048 -0.6581  0.9766  0.1508  0.09    0.9232 -0.3461  0.3708 -0.6573
#  -0.2511  0.7454  0.4394  0.4063 -0.0686 -0.625   0.7395  0.797  -0.8761
#  -0.5764  0.327   0.0232  0.0688  0.4262 -0.6164 -0.556  -0.1975  0.7215
#   0.3564 -0.1938 -0.8422 -0.3938  0.5571  0.5061  0.9304 -0.2601 -0.5525
#  -0.1221 -0.5084 -0.3949]
# [-0.9801  0.2966  0.4645  0.264  -0.2714  0.2519 -0.8603  0.0028  0.2703
#  -0.4116  0.6897  0.7237 -0.9232 -0.8121  0.828  -0.583  -0.2266  0.0379
#  -0.1116  0.6606  0.4262  0.5948  0.3704  0.0106  0.6526  0.7756  0.8902
#  -0.2416 -0.0272  0.9618  0.4435  0.6297 -0.4585  0.1993  0.7272  0.26
#   0.3786 -0.6908  0.3105]
